# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from matplotlib import pyplot
import feather
import warnings
from IPython.display import display
from folium.plugins import HeatMap
#import ipyleaflet
#from ipyleaflet import MarkerCluster, basemaps, CircleMarker
import folium
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

warnings.filterwarnings('ignore')

# %%
# hv = pd.read_csv("hv_cleaned.csv", index_col = [0]) # index_col = [0] removes unnmaed index column
# path = 'hv_cleaned.feather'
# feather.write_dataframe(hv, path)
# hv = feather.read_dataframe(path)

# %%
# hv["Date"] =  pd.to_datetime(hv["Date"], format="%m/%d/%Y")
# hv['Year'] = hv['Date'].dt.year
# hv['Month'] = hv['Date'].dt.month

# %%
# mba_df2 = pd.read_csv("mba_df2.csv", index_col = [0]) # index_col = [0] removes unnmaed index column
# path = 'mba_df2.feather'
# feather.write_dataframe(mba_df2, path)
# mb = feather.read_dataframe(path)

# %%
# transactions = []
# for i in range(0, 18110):
#   transactions.extend(mb["Item Description"])

# %% [markdown]
# - An association rule implies that if an item A occurs, then item B also occurs with a certain probability.
#     - Support is an indication of how frequently the item set appears in the data set.
#         - the number of transactions with both X and Y divided by the total number of transactions.
#     - For a rule X⇒Y, confidence shows the percentage in which Y is bought with X. It’s an indication of how often the rule has been found to be true.
#         - For example, the rule T-shirt⇒Trousers has a confidence of 3/4, which means that for 75% of the transactions containing a t-shirt the rule is correct (75% of the times a customer buys a t-shirt, trousers are bought as well)
#     - The lift of a rule is the ratio of the observed support to that expected if X and Y were independent
#         - Greater lift values indicate stronger associations

# %%
mba_df = pd.read_csv("mba_df.csv", index_col = [0]) # index_col = [0] removes unnmaed index column
path = 'mba_df.feather'
feather.write_dataframe(mba_df, path)
mba_df = feather.read_dataframe(path)

# %%
mba_df.head()
# Out:
#    Store Number        Date  Month  Year                         0  \
# 0          2500  2016-03-23      3  2016             Hawkeye Vodka
# 1          2500  2016-03-30      3  2016        Popov Vodka 80 Prf
# 2          2500  2016-04-13      4  2016                  Old Crow
# 3          2500  2016-04-20      4  2016  Burnett's Gin London Dry
# 4          2500  2016-04-27      4  2016          Southern Comfort
#
#                       1                          2                    3  \
# 0                  None                       None                 None
# 1              Old Crow  Captain Morgan Spiced Rum        Five Star Pet
# 2  Paramount Triple Sec    Bushmills Irish Whiskey                 None
# 3       Bacardi 151 Prf  Bailey's Vanilla Cinnamon  1800 Silver Tequila
# 4                  None                       None                 None
#
#                     4                     5  ...   820   821   822   823  \
# 0                None                  None  ...  None  None  None  None
# 1  Three Olives Vodka  Johnnie Walker Black  ...  None  None  None  None
# 2                None                  None  ...  None  None  None  None
# 3                None                  None  ...  None  None  None  None
# 4                None                  None  ...  None  None  None  None
#
#     824   825   826   827   828   829
# 0  None  None  None  None  None  None
# 1  None  None  None  None  None  None
# 2  None  None  None  None  None  None
# 3  None  None  None  None  None  None
# 4  None  None  None  None  None  None
#
# [5 rows x 834 columns]

# %%
mba_df.shape
# Out:
# (18110, 834)

# %%
num_rows = 18110
num_cols = 834
transactions = mba_df.iloc[:num_rows, 4:num_cols].astype(str).values.tolist()

# %%
from apyori import apriori
rules = apriori(transactions =transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)

# %%
results = list(rules)

# %%
results[:-1]
# Out:
# [RelationRecord(items=frozenset({'1800 Reposado', '1800 Anejo'}), support=0.003865267807840972, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1800 
margarita'}), items_add=frozenset({'Jose Cuervo Authentic Mango Margarita'}), confidence=0.28253968253968254, lift=3.1180948511844306)]),
#  RelationRecord(items=frozenset({'Jose Cuervo Authentic Watermelon Margarita', '1800 Ultimate Watermelon Margarita'}), support=0.0034787410270568746, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1800 Ultimate Watermelon Margarita'}), items_add=frozenset({'Jose Cuervo Authentic Watermelon Margarita'}), confidence=0.2, lift=3.245519713261649)]),
#  RelationRecord(items=frozenset({'360 Huckleberry', '360 Double Chocolate'}), support=0.005356156819436775, ordered_statistics=[OrderedStatistic(items_base=frozenset({'360 Huckleberry'}), items_add=frozenset({'360 Double Chocolate'}), confidence=0.24069478908188585, lift=5.668377932734659)]),
#  RelationRecord(items=frozenset({'360 Huckleberry', '360 Georgia Peach'}), support=0.005135284373274434, ordered_statistics=[OrderedStatistic(items_base=frozenset({'360 Huckleberry'}), items_add=frozenset({'360 Georgia Peach'}), confidence=0.23076923076923078, lift=5.724973656480506)]),
#  RelationRecord(items=frozenset({'360 Vodka', 'Caravella Limoncello'}), support=0.00447266703478741, ordered_statistics=[OrderedStatistic(items_base=frozenset({'360 Vodka'}), items_add=frozenset({'Caravella Limoncello'}), confidence=0.2368421052631579, lift=3.179548203347509)]),
#  RelationRecord(items=frozenset({'360 Vodka', 'Evan Williams Honey'}), support=0.0039204859193815575, ordered_statistics=[OrderedStatistic(items_base=frozenset({'360 Vodka'}), items_add=frozenset({'Evan Williams Honey'}), confidence=0.20760233918128657, lift=3.2721308638582247)]),
#  RelationRecord(items=frozenset({'Exotico Blanco', '360 Vodka'}), support=0.0039204859193815575, ordered_statistics=[OrderedStatistic(items_base=frozenset({'360 Vodka'}), items_add=frozenset({'Exotico Blanco'}), confidence=0.20760233918128657, lift=3.347888123395458)]),
#  RelationRecord(items=frozenset({'Fleischmanns Gin', '360 Vodka'}), support=0.005024848150193263, ordered_statistics=[OrderedStatistic(items_base=frozenset({'360 Vodka'}), items_add=frozenset({'Fleischmanns Gin'}), confidence=0.26608187134502925, lift=3.0287509051278945)]),
#  RelationRecord(items=frozenset({'360 Vodka', 'Pearl Cucumber'}), support=0.004638321369409166, ordered_statistics=[OrderedStatistic(items_base=frozenset({'360 Vodka'}), items_add=frozenset({'Pearl Cucumber'}), confidence=0.2456140350877193, lift=3.0095197398096056)]),
#  RelationRecord(items=frozenset({'360 Vodka', 'Romana Sambuca Italian Liquore'}), support=0.0043070127001656544, ordered_statistics=[OrderedStatistic(items_base=frozenset({'360 Vodka'}), items_add=frozenset({'Romana Sambuca Italian Liquore'}), confidence=0.2280701754385965, lift=3.219291408568186)]),
#  RelationRecord(items=frozenset({'360 Vodka', 'Sauza Blanco Silver'}), support=0.0043070127001656544, ordered_statistics=[OrderedStatistic(items_base=frozenset({'360 Vodka'}), items_add=frozenset({'Sauza Blanco Silver'}), confidence=0.2280701754385965, lift=3.405070797356127)]),
#  RelationRecord(items=frozenset({'360 Vodka', 'Smirnoff Citrus'}), support=0.0045278851463279954, ordered_statistics=[OrderedStatistic(items_base=frozenset({'360 Vodka'}), items_add=frozenset({'Smirnoff Citrus'}), confidence=0.23976608187134504, lift=4.151208167007704)]),
#  RelationRecord(items=frozenset({'99 Bananas', '99 Apples'}), support=0.010436223081170624, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Apples'}), items_add=frozenset({'99 Bananas'}), confidence=0.3572778827977316, lift=3.1077341294269543)]),
#  RelationRecord(items=frozenset({'99 Blackberries', '99 Apples'}), support=0.007012700165654335, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Apples'}), items_add=frozenset({'99 Blackberries'}), confidence=0.2400756143667297, lift=6.617609400580632)]),
#  RelationRecord(items=frozenset({'99 Peaches', '99 Apples'}), support=0.006957482054113749, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Apples'}), items_add=frozenset({'99 Peaches'}), confidence=0.2381852551984877, lift=8.71421206392851), OrderedStatistic(items_base=frozenset({'99 Peaches'}), items_add=frozenset({'99 Apples'}), confidence=0.2545454545454546, lift=8.714212063928512)]),
#  RelationRecord(items=frozenset({'99 Pineapple', '99 Apples'}), support=0.005466593042517946, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Pineapple'}), items_add=frozenset({'99 Apples'}), confidence=0.27808988764044945, lift=9.520241711093648)]),
#  RelationRecord(items=frozenset({'99 Apples', '99 Root Beer'}), support=0.006018774157923799, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Apples'}), items_add=frozenset({'99 Root Beer'}), confidence=0.20604914933837432, lift=7.939468286208424), OrderedStatistic(items_base=frozenset({'99 Root Beer'}), items_add=frozenset({'99 Apples'}), confidence=0.2319148936170213, lift=7.939468286208423)]),
#  RelationRecord(items=frozenset({'99 Blackberries', '99 Bananas'}), support=0.014191054665930425, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blackberries'}), items_add=frozenset({'99 Bananas'}), confidence=0.39117199391172, lift=3.4025575455049224)]),
#  RelationRecord(items=frozenset({'99 Bananas', '99 Cinnamon'}), support=0.007012700165654335, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Cinnamon'}), items_add=frozenset({'99 Bananas'}), confidence=0.4519572953736655, lift=3.931290403082172)]),
#  RelationRecord(items=frozenset({'99 Grapes', '99 Bananas'}), support=0.012644947542794037, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Grapes'}), items_add=frozenset({'99 Bananas'}), confidence=0.5252293577981652, lift=4.5686376895892264)]),
#  RelationRecord(items=frozenset({'99 Mangoes', '99 Bananas'}), support=0.011098840419657648, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Mangoes'}), items_add=frozenset({'99 Bananas'}), confidence=0.6340694006309149, lift=5.515368321530196)]),
#  RelationRecord(items=frozenset({'99 Bananas', '99 Peaches'}), support=0.01131971286581999, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Peaches'}), items_add=frozenset({'99 Bananas'}), confidence=0.4141414141414142, lift=3.602353991402983)]),
#  RelationRecord(items=frozenset({'99 Bananas', '99 Peppermint'}), support=0.011927112092766427, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Peppermint'}), items_add=frozenset({'99 Bananas'}), confidence=0.41221374045801523, lift=3.5855863783355693)]),
#  RelationRecord(items=frozenset({'99 Bananas', '99 Pineapple'}), support=0.008282716731087797, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Pineapple'}), items_add=frozenset({'99 Bananas'}), confidence=0.4213483146067416, lift=3.665042256257488)]),
#  RelationRecord(items=frozenset({'99 Bananas', '99 Root Beer'}), support=0.010104914411927112, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Root Beer'}), items_add=frozenset({'99 Bananas'}), confidence=0.3893617021276596, lift=3.386810963271813)]),
#  RelationRecord(items=frozenset({'99 Bananas', 'Grays Peak Vodka'}), support=0.0038100496963003865, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Grays Peak Vodka'}), items_add=frozenset({'99 Bananas'}), confidence=0.43670886075949367, lift=3.798653923321052)]),
#  RelationRecord(items=frozenset({'99 Blue Raspberries', '99 Bananas Mini'}), support=0.0043622308117062395, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries'}), items_add=frozenset({'99 Bananas Mini'}), confidence=0.3623853211009174, lift=3.5113954869650157)]),
#  RelationRecord(items=frozenset({'99 Blue Raspberries Mini', '99 Bananas Mini'}), support=0.009828823854224185, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries Mini'}), items_add=frozenset({'99 Bananas Mini'}), confidence=0.3946784922394678, lift=3.8243057755252874)]),
#  RelationRecord(items=frozenset({'99 Cinnamon Mini', '99 Bananas Mini'}), support=0.021479845389287686, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Bananas Mini'}), items_add=frozenset({'99 Cinnamon Mini'}), confidence=0.2081326912787587, lift=3.754265975157689), OrderedStatistic(items_base=frozenset({'99 Cinnamon Mini'}), items_add=frozenset({'99 Bananas Mini'}), confidence=0.38745019920318724, lift=3.754265975157689)]),
#  RelationRecord(items=frozenset({'99 Grapes PET Mini', '99 Bananas Mini'}), support=0.0038100496963003865, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Grapes PET Mini'}), items_add=frozenset({'99 Bananas Mini'}), confidence=0.38121546961325964, lift=3.6938534803082566)]),
#  RelationRecord(items=frozenset({'99 Lemon Lime', '99 Bananas Mini'}), support=0.003368304803975704, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Lemon Lime'}), items_add=frozenset({'99 Bananas Mini'}), confidence=0.4178082191780822, lift=4.048425280532407)]),
#  RelationRecord(items=frozenset({'99 Lemon Lime Mini', '99 Bananas Mini'}), support=0.006129210381004969, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 
ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries Mini'}), items_add=frozenset({'99 Root Beer Mini'}), confidence=0.3924611973392461, lift=4.881505689432519)]),
#  RelationRecord(items=frozenset({'99 Strawberries Mini', '99 Blue Raspberries Mini'}), support=0.009718387631143015, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries Mini'}), items_add=frozenset({'99 Strawberries Mini'}), confidence=0.3902439024390244, lift=10.010364126304154), OrderedStatistic(items_base=frozenset({'99 Strawberries Mini'}), items_add=frozenset({'99 Blue Raspberries Mini'}), confidence=0.2492917847025496, lift=10.010364126304154)]),
#  RelationRecord(items=frozenset({'99 Watermelon PET Mini', '99 Blue Raspberries Mini'}), support=0.003202650469353948, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Watermelon PET Mini'}), items_add=frozenset({'99 Blue Raspberries Mini'}), confidence=0.33918128654970764, lift=13.619896007572518)]),
#  RelationRecord(items=frozenset({'Admiral Nelson Spiced', '99 Blue Raspberries Mini'}), support=0.013638873550524571, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries Mini'}), items_add=frozenset({'Admiral Nelson Spiced'}), confidence=0.5476718403547671, lift=3.2551155329257737)]),
#  RelationRecord(items=frozenset({'Deep Eddy Lemon Mini', '99 Blue Raspberries Mini'}), support=0.005742683600220872, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries Mini'}), items_add=frozenset({'Deep Eddy Lemon Mini'}), confidence=0.23059866962305986, lift=3.660071785165306)]),
#  RelationRecord(items=frozenset({'99 Blue Raspberries Mini', 'Dr McGillicuddys Apple Pie Mini'}), support=0.005080066261733848, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries Mini'}), items_add=frozenset({'Dr McGillicuddys Apple Pie Mini'}), confidence=0.2039911308203991, lift=3.5050088986313357)]),
#  RelationRecord(items=frozenset({'Fireball Cinnamon Whiskey Mini Sleeve', '99 Blue Raspberries Mini'}), support=0.009994478188845942, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries Mini'}), items_add=frozenset({'Fireball Cinnamon Whiskey Mini Sleeve'}), confidence=0.40133037694013307, lift=4.280384644514611)]),
#  RelationRecord(items=frozenset({'Fireball Cinnamon Whiskey Party Bucket', '99 Blue Raspberries Mini'}), support=0.010104914411927112, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries Mini'}), items_add=frozenset({'Fireball Cinnamon Whiskey Party Bucket'}), confidence=0.4057649667405765, lift=3.143029746651771)]),
#  RelationRecord(items=frozenset({'99 Blue Raspberries Mini', 'Malibu Coconut'}), support=0.013252346769740474, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries Mini'}), items_add=frozenset({'Malibu Coconut'}), confidence=0.532150776053215, lift=3.129993684418228)]),
#  RelationRecord(items=frozenset({'New Amsterdam Pink Whitney Mini', '99 Blue Raspberries Mini'}), support=0.006736609607951408, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries Mini'}), items_add=frozenset({'New Amsterdam Pink Whitney Mini'}), confidence=0.270509977827051, lift=3.542252854987631)]),
#  RelationRecord(items=frozenset({'RumChata', '99 Blue Raspberries Mini'}), support=0.009828823854224185, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries Mini'}), items_add=frozenset({'RumChata'}), confidence=0.3946784922394678, lift=3.166870843800072)]),
#  RelationRecord(items=frozenset({'RumChata Mini', '99 Blue Raspberries Mini'}), support=0.005024848150193263, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries Mini'}), items_add=frozenset({'RumChata Mini'}), confidence=0.2017738359201774, lift=3.6107946329193803)]),
#  RelationRecord(items=frozenset({'99 Blue Raspberries Mini', 'SOOH 99 Cherries Mini'}), support=0.0034787410270568746, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SOOH 99 Cherries Mini'}), items_add=frozenset({'99 Blue Raspberries Mini'}), confidence=0.315, lift=12.648891352549889)]),
#  RelationRecord(items=frozenset({'99 Blue Raspberries Mini', 'Skrewball Peanut Butter Whiskey Mini'}), support=0.00530093870789619, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Blue Raspberries Mini'}), items_add=frozenset({'Skrewball Peanut Butter Whiskey Mini'}), confidence=0.21286031042128603, lift=5.429436932013367)]),
#  RelationRecord(items=frozenset({'99 Brand Fruit Punch PET Mini', '99 Brand Cherry Limeade PET Mini'}), support=0.003202650469353948, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 
ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Oranges Mini'}), items_add=frozenset({'99 Cinnamon Mini'}), confidence=0.26999999999999996, lift=4.870219123505976)]),
#  RelationRecord(items=frozenset({'99 Peanut Butter Whiskey Mini', '99 Cinnamon Mini'}), support=0.0039757040309221425, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Peanut Butter Whiskey Mini'}), items_add=frozenset({'99 Cinnamon Mini'}), confidence=0.25, lift=4.509462151394422)]),
#  RelationRecord(items=frozenset({'99 Cinnamon Mini', '99 Peppermint Mini'}), support=0.02192159028161237, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Cinnamon Mini'}), items_add=frozenset({'99 Peppermint Mini'}), confidence=0.39541832669322713, lift=3.947643823822681), OrderedStatistic(items_base=frozenset({'99 Peppermint Mini'}), items_add=frozenset({'99 Cinnamon Mini'}), confidence=0.21885336273428888, lift=3.947643823822681)]),
#  RelationRecord(items=frozenset({'99 Cinnamon Mini', '99 Pineapple Mini'}), support=0.013252346769740474, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Cinnamon Mini'}), items_add=frozenset({'99 Pineapple Mini'}), confidence=0.2390438247011952, lift=5.445388258287603), OrderedStatistic(items_base=frozenset({'99 Pineapple Mini'}), items_add=frozenset({'99 Cinnamon Mini'}), confidence=0.3018867924528302, lift=5.445388258287604)]),
#  RelationRecord(items=frozenset({'99 Cinnamon Mini', '99 Root Beer Mini'}), support=0.020209828823854224, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Cinnamon Mini'}), items_add=frozenset({'99 Root Beer Mini'}), confidence=0.3645418326693227, lift=4.5342394159625234), OrderedStatistic(items_base=frozenset({'99 Root Beer Mini'}), items_add=frozenset({'99 Cinnamon Mini'}), confidence=0.25137362637362637, lift=4.5342394159625234)]),
#  RelationRecord(items=frozenset({'99 Strawberries Mini', '99 Cinnamon Mini'}), support=0.009607951408061845, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Strawberries Mini'}), items_add=frozenset({'99 Cinnamon Mini'}), confidence=0.2464589235127479, lift=4.445588749816598)]),
#  RelationRecord(items=frozenset({'99 Cinnamon Mini', 'Captain Morgan Apple Smash Mini'}), support=0.003202650469353948, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain Morgan Apple Smash Mini'}), items_add=frozenset({'99 Cinnamon Mini'}), confidence=0.20494699646643108, lift=3.6968028944293496)]),
#  RelationRecord(items=frozenset({'99 Cinnamon Mini', 'Jim Beam Honey Mini'}), support=0.012976256212037547, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Cinnamon Mini'}), items_add=frozenset({'Jim Beam Honey Mini'}), confidence=0.2340637450199203, lift=3.094083519934859)]),
#  RelationRecord(items=frozenset({'Kessler Blend Whiskey Mini', '99 Cinnamon Mini'}), support=0.00353395913859746, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kessler Blend Whiskey Mini'}), items_add=frozenset({'99 Cinnamon Mini'}), confidence=0.20846905537459287, lift=3.760333259794698)]),
#  RelationRecord(items=frozenset({'99 Cinnamon Mini', 'SOOH 99 Cherries Mini'}), support=0.0034235229155162895, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SOOH 99 Cherries Mini'}), items_add=frozenset({'99 Cinnamon Mini'}), confidence=0.31, lift=5.591733067729083)]),
#  RelationRecord(items=frozenset({'Fireball Cinnamon Whiskey 100ml Carrier', '99 Fruits 10PK'}), support=0.0031474323578133626, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Fruits 10PK'}), items_add=frozenset({'Fireball Cinnamon Whiskey 100ml Carrier'}), confidence=0.3540372670807453, lift=3.0101478435832383)]),
#  RelationRecord(items=frozenset({'99 Fruits 10PK', 'Fireball Cinnamon Whiskey 50ml Sleeve'}), support=0.003368304803975704, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Fruits 10PK'}), items_add=frozenset({'Fireball Cinnamon Whiskey 50ml Sleeve'}), confidence=0.37888198757763975, lift=4.499378881987577)]),
#  RelationRecord(items=frozenset({'Admiral Nelson Spiced', '99 Fruits Mini'}), support=0.00541137493097736, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Fruits Mini'}), items_add=frozenset({'Admiral Nelson Spiced'}), confidence=0.5240641711229946, lift=3.114802146057576)]),
#  RelationRecord(items=frozenset({'Fireball Cinnamon Whiskey Mini Sleeve', '99 Fruits Mini'}), support=0.004803975704030922, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Fruits Mini'}), items_add=frozenset({'Fireball Cinnamon Whiskey Mini Sleeve'}), confidence=0.46524064171123, lift=4.962018858298218)]),
#  RelationRecord(items=frozenset({'Malibu Coconut', '99 Fruits Mini'}), support=0.005908337934842628, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Fruits Mini'}), items_add=frozenset({'Malibu Coconut'}), confidence=0.5721925133689839, lift=3.3655103660644037)]),
#  RelationRecord(items=frozenset({'RumChata', '99 Fruits Mini'}), support=0.00447266703478741, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Fruits Mini'}), items_add=frozenset({'RumChata'}), confidence=0.43315508021390375, lift=3.4756041216986255)]),
#  RelationRecord(items=frozenset({'99 Grapes', '99 Mangoes'}), support=0.008448371065709552, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Grapes'}), items_add=frozenset({'99 Mangoes'}), confidence=0.3509174311926605, lift=20.04768037507597), OrderedStatistic(items_base=frozenset({'99 Mangoes'}), items_add=frozenset({'99 Grapes'}), confidence=0.48264984227129337, lift=20.04768037507597)]),
#  RelationRecord(items=frozenset({'99 Grapes', '99 Peppermint'}), support=0.007454445057979017, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Grapes'}), items_add=frozenset({'99 Peppermint'}), confidence=0.30963302752293576, lift=10.701248336718256), OrderedStatistic(items_base=frozenset({'99 Peppermint'}), items_add=frozenset({'99 Grapes'}), confidence=0.25763358778625955, lift=10.701248336718258)]),
#  RelationRecord(items=frozenset({'99 Grapes', '99 Root Beer Mini'}), support=0.005908337934842628, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Grapes'}), items_add=frozenset({'99 Root Beer Mini'}), confidence=0.24541284403669725, lift=3.0524908004839197)]),
#  RelationRecord(items=frozenset({'99 Peppermint Mini', '99 Grapes PET Mini'}), support=0.003699613473219216, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Grapes PET Mini'}), items_add=frozenset({'99 Peppermint Mini'}), confidence=0.3701657458563536, lift=3.6955356435824496)]),
#  RelationRecord(items=frozenset({'99 Root Beer Mini', '99 Grapes PET Mini'}), support=0.0039757040309221425, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Grapes PET Mini'}), items_add=frozenset({'99 Root Beer Mini'}), confidence=0.39779005524861877, lift=4.947787019610224)]),
#  RelationRecord(items=frozenset({'99 Strawberries Mini', '99 Grapes PET Mini'}), support=0.0034787410270568746, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Grapes PET Mini'}), items_add=frozenset({'99 Strawberries Mini'}), confidence=0.34806629834254144, lift=8.928442865415617)]),
#  RelationRecord(items=frozenset({'99 Lemon Lime', '99 Peppermint Mini'}), support=0.003368304803975704, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99 Lemon Lime'}), items_add=frozenset({'99 Peppermint Mini'}), confidence=0.4178082191780822, lift=4.171172463790005)]),
# ...
#  RelationRecord(items=frozenset({'Buffalo Trace Bourbon', 'Crown Royal Salted Caramel'}), support=0.0030922142462727776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Crown Royal Salted Caramel'}), items_add=frozenset({'Buffalo Trace Bourbon'}), confidence=0.37837837837837834, lift=3.1447601800974905)]),
#  RelationRecord(items=frozenset({'Buffalo Trace Bourbon', 'Eagle Rare'}), support=0.04080618442849254, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Buffalo Trace Bourbon'}), items_add=frozenset({'Eagle Rare'}), confidence=0.33914639743001374, lift=7.251406443279278), OrderedStatistic(items_base=frozenset({'Eagle Rare'}), items_add=frozenset({'Buffalo Trace Bourbon'}), confidence=0.8724911452184179, lift=7.251406443279278)]),
#  RelationRecord(items=frozenset({'Buffalo Trace Bourbon', 'Henry Mckenna Single Barrel 10YR'}), support=0.0040309221424627275, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Henry Mckenna Single Barrel 10YR'}), items_add=frozenset({'Buffalo Trace Bourbon'}), confidence=0.9240506329113923, lift=7.679925177616023)]),
#  RelationRecord(items=frozenset({'Buffalo Trace Bourbon', 'Michters US*1 Small Batch Bourbon'}), support=0.003865267807840972, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Michters US*1 Small Batch Bourbon'}), items_add=frozenset({'Buffalo Trace Bourbon'}), confidence=0.43478260869565216, lift=3.613544306323204)]),
#  RelationRecord(items=frozenset({'Buffalo Trace Bourb
ordered_statistics=[OrderedStatistic(items_base=frozenset({'Burnetts Fruit Punch'}), items_add=frozenset({'Burnetts Raspberry'}), confidence=0.29197080291970806, lift=5.710141728807681)]),
#  ...]

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
resultsinDataFrame
# Out:
#                             Left Hand Side  \
# 0                               1800 Anejo
# 1                             1800 Coconut
# 2                          1800 Cristalino
# 3                            1800 Reposado
# 4     1800 Ultimate Blood Orange Margarita
# ...                                    ...
# 3430                  Woodford Reserve Rye
# 3431     Woodford Reserve Straight Bourbon
# 3432        Woodford Reserve Straight Malt
# 3433                 Zaya Gran Reserva Rum
# 3434        Woodford Reserve Straight Malt
#
#                              Right Hand Side   Support  Confidence      Lift
# 0                              1800 Reposado  0.003865    0.260223  4.593216
# 1                              1800 Reposado  0.003644    0.247191  4.363186
# 2     Fireball Cinnamon Whiskey Party Bucket  0.003810    0.418182  3.239210
# 3                                1800 Silver  0.022253    0.392788  3.371271
# 4                    1800 Ultimate Margarita  0.004638    0.409756  3.651911
# ...                                      ...       ...         ...       ...
# 3430           Woodford Reserve Double Oaked  0.010602    0.349727  5.191436
# 3431           Woodford Reserve Double Oaked  0.009332    0.269108  3.994714
# 3432           Woodford Reserve Double Oaked  0.003092    0.267943  3.977410
# 3433           Woodford Reserve Double Oaked  0.004307    0.203655  3.023113
# 3434                    Woodford Reserve Rye  0.003313    0.287081  9.470024
#
# [3435 rows x 5 columns]

# %%
resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                     Left Hand Side           Right Hand Side   Support  \
# 3380    Truly Pineapple Mango Mini     Truly Wild Berry Mini  0.003313
# 3426        White Dog Straight Rye           White Dog Wheat  0.004638
# 3425             White Dog Mash #1           White Dog Wheat  0.004749
# 3424             White Dog Mash #1    White Dog Straight Rye  0.004528
# 3381  Twisted Shotz Buttery Nipple  Twisted Shotz Miami Vice  0.003258
#
#       Confidence        Lift
# 3380    0.983607  269.895678
# 3426    0.988235  201.089227
# 3425    0.966292  196.624164
# 3424    0.921348  196.301388
# 3381    0.590000  136.985897

# %% [markdown]
# - Look at the different levels of support, confidence, and lift to see if there is anything meaningful in those associations.
# - Do some deeper investigating in order to pull out some of the more meaningful MBA results, but sorting by the confidence and lift will be a good start.

# %% [markdown]
# # What happens if we condition on the month, report your findings for different months.

# %% [markdown]
# ## January

# %%
jan_mba = mba_df[mba_df["Month"] == 1]
jan_mba.shape
# Out:
# (1901, 834)

# %%
num_rows = 1901
num_cols = 834
jan_transactions = mba_df.iloc[:num_rows, 4:num_cols].astype(str).values.tolist()

# %%
len(jan_transactions)
# Out:
# 1901

# %%
rules = apriori(transactions = jan_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)

# %%
jan_results = list(rules)

# %%
jan_results[:2]
# Out:
# [RelationRecord(items=frozenset({'Bacardi Superior Mini', '1792 Bottle in Bond Bourbon'}), support=0.003156233561283535, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1792 Bottle in Bond Bourbon'}), items_add=frozenset({'Bacardi Superior Mini'}), confidence=0.5, lift=3.5733082706766917)]),
#  RelationRecord(items=frozenset({'1792 Bottle in Bond Bourbon', 'Crown Royal Mini'}), support=0.003156233561283535, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1792 Bottle in Bond Bourbon'}), items_add=frozenset({'Crown Royal Mini'}), confidence=0.5, lift=3.2551369863013697)])]

# %%
def inspect(jan_results):
    lhs         = [tuple(result[2][0][0])[0] for result in jan_results]
    rhs         = [tuple(result[2][0][1])[0] for result in jan_results]
    supports    = [result[1] for result in jan_results]
    confidences = [result[2][0][2] for result in jan_results]
    lifts       = [result[2][0][3] for result in jan_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

jan_resultsinDataFrame = pd.DataFrame(inspect(jan_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
jan_resultsinDataFrame.sort_values(by=["Confidence"], ascending = False).head()
# Out:
#                                Left Hand Side  \
# 16447  Grey Goose Essences Watermelon & Basil
# 5351      Cody Road Barrel Old Fashioned Mini
# 16443      Laphroaig 10 Yr Single Malt Scotch
# 20659                     Mt. Gay Eclipse Rum
# 19372      Laphroaig 10 Yr Single Malt Scotch
#
#                                   Right Hand Side   Support  Confidence  \
# 16447  Grey Goose Essences White Peach & Rosemary  0.004208         1.0
# 5351                     Bird Dog Blackberry Mini  0.003156         1.0
# 16443                                  Grey Goose  0.004208         1.0
# 20659                           New Amsterdam Gin  0.004734         1.0
# 19372                         Mccormick Vodka Pet  0.004208         1.0
#
#              Lift
# 16447  135.785714
# 5351    22.903614
# 16443    3.003160
# 20659    4.150655
# 19372   41.326087

# %%
jan_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                           Left Hand Side  \
# 23737          Truly Strawberry Lemonade
# 23735              Truly Pineapple Mango
# 23734              Truly Pineapple Mango
# 15056                  Flecha Azul Anejo
# 20683  Natural Light Lemonade Vodka Mini
#
#                                     Right Hand Side   Support  Confidence  \
# 23737                              Truly Wild Berry  0.003156    1.000000
# 23735                              Truly Wild Berry  0.003156    1.000000
# 23734                     Truly Strawberry Lemonade  0.003156    1.000000
# 15056                          Flecha Azul Reposado  0.003156    1.000000
# 20683  Natural Light Strawberry Lemonade Vodka Mini  0.003156    0.857143
#
#              Lift
# 23737  316.833333
# 23735  316.833333
# 23734  316.833333
# 15056  271.571429
# 20683  271.571429

# %%
jan_resultsinDataFrame[(jan_resultsinDataFrame["Lift"] >= 100) & (jan_resultsinDataFrame["Confidence"] >= 0.5)]
# Out:
#                                        Left Hand Side  \
# 5106                               Belvedere Bartezek
# 6519                               Branson VS Phantom
# 9693                               Chivas Regal 12 Yr
# 11513                Daviess County KSBW Cab Finished
# 13894     Elijah Craig w/Old Fashioned Cocktail Syrup
# 14897               Fireball Countdown Calendar Minis
# 15055                               Flecha Azul Anejo
# 15056                               Flecha Azul Anejo
# 15057                              Flecha Azul Blanco
# 16447          Grey Goose Essences Watermelon & Basil
# 16448          Grey Goose Essences Watermelon & Basil
# 16449      Grey Goose Essences White Peach & Rosemary
# 16505                     HA Kentucky Owl Confiscated
# 17214                Hornitos Lime Hibiscus Margarita
# 17619              Issac Bowman Port Finished Bourbon
# 17620              Issac Bowman Port Finished Bourbon
# 18487                           John J Bowman Bourbon
# 20193                            McCormick Vodka Mini
# 20682  Natural Light Black Cherry Lemonade Vodka Mini
# 20683               Natural Light Lemonade Vodka Mini
# 22506                        Rich & Rare Caramel Mini
# 22507                        Rich & Rare Caramel Mini
# 22509                                Rich & Rare Mini
# 23680                        Three Olives Pomegranate
# 23734                           Truly Pineapple Mango
# 23735                           Truly Pineapple Mango
# 23736                      Truly Pineapple Mango Mini
# 23737                       Truly Strawberry Lemonade
# 23740                    Twisted Shotz Buttery Nipple
# 23741                    Twisted Shotz Buttery Nipple
# 23797                               White Dog Mash #1
# 23798                               White Dog Mash #1
# 23799                          White Dog Straight Rye
#
#                                         Right Hand Side   Support  Confidence  \
# 5106                                  Belvedere Smogory  0.003156    0.545455
# 6519                      Branson VSOP Grande Champagne  0.004734    0.692308
# 9693                                Mt. Gay Eclipse Rum  0.003156    0.500000
# 11513  Daviess County Kentucky Straight Bourbon Whiskey  0.003682    0.583333
# 13894                    Larceny  VAP w/Glass and Flask  0.003156    0.666667
# 14897                   Fireball Holiday Ornament Minis  0.003156    0.666667
# 15055                                Flecha Azul Blanco  0.003156    1.000000
# 15056                              Flecha Azul Reposado  0.003156    1.000000
# 15057                              Flecha Azul Reposado  0.003682    0.875000
# 16447        Grey Goose Essences White Peach & Rosemary  0.004208    1.000000
# 16448                Grey Goose Strawberry & Lemongrass  0.004208    1.000000
# 16449                Grey Goose Strawberry & Lemongrass  0.004734    0.642857
# 16505                   HA Kentucky Owl Rye  - Batch #4  0.003682    0.500000
# 17214            Hornitos Strawberry Tamarind Margarita  0.003156    0.750000
# 17619                             John J Bowman Bourbon  0.004208    0.800000
# 17620                               Very Old Barton 6YR  0.003156    0.600000
# 18487                               Very Old Barton 6YR  0.003156    0.666667
# 20193                      Rumple Minze Peppermint Mini  0.003682    0.777778
# 20682                 Natural Light Lemonade Vodka Mini  0.003156    1.000000
# 20683      Natural Light Strawberry Lemonade Vodka Mini  0.003156    0.857143
# 22506                                  Rich & Rare Mini  0.003156    0.666667
# 22507                            Rich & Rare Peach Mini  0.003682    0.777778
# 22509                            Rich & Rare Peach Mini  0.003156    1.000000
# 23680                            Three Olives Raspberry  0.003156    0.750000
# 23734                         Truly Strawberry Lemonade  0.003156    1.000000
# 23735                                  Truly Wild Berry  0.003156    1.000000
# 23736                             Truly Wild Berry Mini  0.004734    1.000000
# 23737                                  Truly Wild Berry  0.003156    1.000000
# 23740                          Twisted Shotz Miami Vice  0.003682    0.583333
# 23741          Twisted Shotz Pineapple Upisde Down Cake  0.003682    0.583333
# 23797                            White Dog Straight Rye  0.006312    1.000000
# 23798                                   White Dog Wheat  0.006312    1.000000
# 23799                                   White Dog Wheat  0.006839    1.000000
#
#              Lift
# 5106   129.613636
# 6519   101.236686
# 9693   105.611111
# 11513  158.416667
# 13894  181.047619
# 14897  115.212121
# 15055  237.625000
# 15056  271.571429
# 15057  237.625000
# 16447  135.785714
# 16448  190.100000
# 16449  122.207143
# 16505  135.785714
# 17214  178.218750
# 17619  168.977778
# 17620  162.942857
# 18487  181.047619
# 20193  147.855556
# 20682  271.571429
# 20683  271.571429
# 22506  211.222222
# 22507  147.855556
# 22509  190.100000
# 23680  203.678571
# 23734  316.833333
# 23735  316.833333
# 23736  211.222222
# 23737  316.833333
# 23740  100.810606
# 23741  110.891667
# 23797  146.230769
# 23798  146.230769
# 23799  146.230769

# %% [markdown]
# ## February

# %%
feb_mba = mba_df[mba_df["Month"] == 2]
feb_mba.shape
# Out:
# (1837, 834)

# %%
num_rows = 1837
num_cols = 834
feb_transactions = mba_df.iloc[:num_rows, 4:num_cols].astype(str).values.tolist()

# %%
rules = apriori(transactions = feb_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)

# %%
feb_results = list(rules)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8036/3050105547.py in <module>
# ----> 1 feb_results = list(rules)
#
# ~\anaconda3\lib\site-packages\apyori.py in apriori(transactions, **kwargs)
#     284
#     285     # Calculate ordered stats.
# --> 286     for support_record in support_records:
#     287         ordered_statistics = list(
#     288             _filter_ordered_statistics(
#
# ~\anaconda3\lib\site-packages\apyori.py in gen_support_records(transaction_manager, min_support, **kwargs)
#     197         if max_length and length > max_length:
#     198             break
# --> 199         candidates = _create_next_candidates(relations, length)
#     200
#     201
#
# ~\anaconda3\lib\site-packages\apyori.py in create_next_candidates(prev_candidates, length)
#     155     # Filter candidates that all of their subsets are
#     156     # in the previous candidates.
# --> 157     next_candidates = [
#     158         candidate for candidate in tmp_next_candidates
#     159         if all(
#
# ~\anaconda3\lib\site-packages\apyori.py in <listcomp>(.0)
#     157     next_candidates = [
#     158         candidate for candidate in tmp_next_candidates
# --> 159         if all(
#     160             frozenset(x) in prev_candidates
#     161             for x in combinations(candidate, length - 1))
#
# ~\anaconda3\lib\site-packages\apyori.py in <genexpr>(.0)
#     158         candidate for candidate in tmp_next_candidates
#     159         if all(
# --> 160             frozenset(x) in prev_candidates
#     161             for x in combinations(candidate, length - 1))
#     162     ]
#
# KeyboardInterrupt:

# %%
def inspect(feb_results):
    lhs         = [tuple(result[2][0][0])[0] for result in feb_results]
    rhs         = [tuple(result[2][0][1])[0] for result in feb_results]
    supports    = [result[1] for result in feb_results]
    confidences = [result[2][0][2] for result in feb_results]
    lifts       = [result[2][0][3] for result in feb_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

feb_resultsinDataFrame = pd.DataFrame(inspect(feb_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
feb_resultsinDataFrame.head()

# %% [markdown]
# ## March

# %%
mar_mba = mba_df[mba_df["Month"] == 3]
mar_mba.shape
# Out:
# (2078, 834)

# %%
num_rows = 2078
num_cols = 834
mar_transactions = mba_df.iloc[:num_rows, 4:num_cols].astype(str).values.tolist()

# %%
rules = apriori(transactions = mar_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
mar_results = list(rules)

# %%
def inspect(mar_results):
    lhs         = [tuple(result[2][0][0])[0] for result in mar_results]
    rhs         = [tuple(result[2][0][1])[0] for result in mar_results]
    supports    = [result[1] for result in mar_results]
    confidences = [result[2][0][2] for result in mar_results]
    lifts       = [result[2][0][3] for result in mar_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

mar_resultsinDataFrame = pd.DataFrame(inspect(mar_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
mar_resultsinDataFrame.sort_values(by=["Confidence"], ascending = False).head()
# Out:
#                            Left Hand Side        Right Hand Side   Support  \
# 4955   Laphroaig 10 Yr Single Malt Scotch    Bombay Sapphire Gin  0.003850
# 18750          Truly Pineapple Mango Mini  Truly Wild Berry Mini  0.004331
# 11903                   Flecha Azul Anejo     Flecha Azul Blanco  0.003369
# 18807              White Dog Straight Rye        White Dog Wheat  0.006256
# 10789            Effen Black Cherry Vodka         Effen Cucumber  0.003369
#
#        Confidence        Lift
# 4955          1.0    3.950570
# 18750         1.0  230.888889
# 11903         1.0  230.888889
# 18807         1.0  159.846154
# 10789         1.0   24.738095

# %%
mar_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                    Left Hand Side        Right Hand Side   Support  \
# 11904           Flecha Azul Anejo   Flecha Azul Reposado  0.003369
# 18750  Truly Pineapple Mango Mini  Truly Wild Berry Mini  0.004331
# 11903           Flecha Azul Anejo     Flecha Azul Blanco  0.003369
# 11905          Flecha Azul Blanco   Flecha Azul Reposado  0.003850
# 17770    Rich & Rare Caramel Mini       Rich & Rare Mini  0.003369
#
#        Confidence        Lift
# 11904    1.000000  259.750000
# 18750    1.000000  230.888889
# 11903    1.000000  230.888889
# 11905    0.888889  230.888889
# 17770    0.700000  207.800000

# %%
mar_resultsinDataFrame[(mar_resultsinDataFrame["Lift"] >= 100) & (mar_resultsinDataFrame["Confidence"] >= 0.5)]
# Out:
#                                    Left Hand Side  \
# 5132                           Branson VS Phantom
# 5133                           Branson VS Phantom
# 9093             Daviess County KSBW Cab Finished
# 11771           Fireball Countdown Calendar Minis
# 11903                           Flecha Azul Anejo
# 11904                           Flecha Azul Anejo
# 11905                          Flecha Azul Blanco
# 13133      Grey Goose Essences Watermelon & Basil
# 13134      Grey Goose Essences Watermelon & Basil
# 13135  Grey Goose Essences White Peach & Rosemary
# 14004          Issac Bowman Port Finished Bourbon
# 15955                        McCormick Vodka Mini
# 17768                      Rich & Rare Apple Mini
# 17770                    Rich & Rare Caramel Mini
# 17772                            Rich & Rare Mini
# 18750                  Truly Pineapple Mango Mini
# 18752                Twisted Shotz Buttery Nipple
# 18753                Twisted Shotz Buttery Nipple
# 18754                Twisted Shotz Buttery Nipple
# 18805                           White Dog Mash #1
# 18806                           White Dog Mash #1
# 18807                      White Dog Straight Rye
#
#                                         Right Hand Side   Support  Confidence  \
# 5132                      Branson VSOP Grande Champagne  0.004812    0.714286
# 5133                                 Branson VSOP Royal  0.003369    0.500000
# 9093   Daviess County Kentucky Straight Bourbon Whiskey  0.003369    0.583333
# 11771                   Fireball Holiday Ornament Minis  0.003369    0.700000
# 11903                                Flecha Azul Blanco  0.003369    1.000000
# 11904                              Flecha Azul Reposado  0.003369    1.000000
# 11905                              Flecha Azul Reposado  0.003850    0.888889
# 13133        Grey Goose Essences White Peach & Rosemary  0.003850    0.888889
# 13134                Grey Goose Strawberry & Lemongrass  0.004331    1.000000
# 13135                Grey Goose Strawberry & Lemongrass  0.004331    0.600000
# 14004                             John J Bowman Bourbon  0.003850    0.800000
# 15955                      Rumple Minze Peppermint Mini  0.003369    0.777778
# 17768                            Rich & Rare Peach Mini  0.003369    1.000000
# 17770                                  Rich & Rare Mini  0.003369    0.700000
# 17772                            Rich & Rare Peach Mini  0.003369    1.000000
# 18750                             Truly Wild Berry Mini  0.004331    1.000000
# 18752                          Twisted Shotz Miami Vice  0.003369    0.583333
# 18753          Twisted Shotz Pineapple Upisde Down Cake  0.003369    0.583333
# 18754                    Twisted Shotz Sex on the Beach  0.003850    0.666667
# 18805                            White Dog Straight Rye  0.005775    1.000000
# 18806                                   White Dog Wheat  0.005775    1.000000
# 18807                                   White Dog Wheat  0.006256    1.000000
#
#              Lift
# 5132   106.020408
# 5133   115.444444
# 9093   173.166667
# 11771  121.216667
# 11903  230.888889
# 11904  259.750000
# 11905  230.888889
# 13133  123.140741
# 13134  188.909091
# 13135  113.345455
# 14004  184.711111
# 15955  161.622222
# 17768  122.235294
# 17770  207.800000
# 17772  122.235294
# 18750  230.888889
# 18752  110.196970
# 18753  121.216667
# 18754  106.564103
# 18805  159.846154
# 18806  159.846154
# 18807  159.846154

# %% [markdown]
# ## April

# %%
apr_mba = mba_df[mba_df["Month"] == 4]
apr_mba.shape
# Out:
# (1317, 834)

# %%
num_rows = 1317
num_cols = 834
apr_transactions = mba_df.iloc[:num_rows, 4:num_cols].astype(str).values.tolist()

rules = apriori(transactions = apr_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
apr_results = list(rules)

def inspect(apr_results):
    lhs         = [tuple(result[2][0][0])[0] for result in apr_results]
    rhs         = [tuple(result[2][0][1])[0] for result in apr_results]
    supports    = [result[1] for result in apr_results]
    confidences = [result[2][0][2] for result in apr_results]
    lifts       = [result[2][0][3] for result in apr_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

apr_resultsinDataFrame = pd.DataFrame(inspect(apr_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
apr_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                                        Left Hand Side  \
# 32676                       Truly Strawberry Lemonade
# 32670                           Truly Pineapple Mango
# 28627  Natural Light Black Cherry Lemonade Vodka Mini
# 32671                           Truly Pineapple Mango
# 24241              Issac Bowman Port Finished Bourbon
#
#                          Right Hand Side   Support  Confidence    Lift
# 32676                   Truly Wild Berry  0.003037         1.0  329.25
# 32670          Truly Strawberry Lemonade  0.003037         1.0  329.25
# 28627  Natural Light Lemonade Vodka Mini  0.003037         1.0  329.25
# 32671                   Truly Wild Berry  0.003037         1.0  329.25
# 24241              John J Bowman Bourbon  0.003037         0.8  263.40

# %%
apr_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                                        Left Hand Side  \
# 32676                       Truly Strawberry Lemonade
# 32670                           Truly Pineapple Mango
# 28627  Natural Light Black Cherry Lemonade Vodka Mini
# 32671                           Truly Pineapple Mango
# 24241              Issac Bowman Port Finished Bourbon
#
#                          Right Hand Side   Support  Confidence    Lift
# 32676                   Truly Wild Berry  0.003037         1.0  329.25
# 32670          Truly Strawberry Lemonade  0.003037         1.0  329.25
# 28627  Natural Light Lemonade Vodka Mini  0.003037         1.0  329.25
# 32671                   Truly Wild Berry  0.003037         1.0  329.25
# 24241              John J Bowman Bourbon  0.003037         0.8  263.40

# %% [markdown]
# ## May

# %%
may_mba = mba_df[mba_df["Month"] == 5]
may_mba.shape
# Out:
# (1263, 834)

# %%
may_mba.head()
# Out:
#     Store Number        Date  Month  Year                        0  \
# 5           2500  2016-05-04      5  2016      Juarez Tequila Gold
# 6           2500  2016-05-11      5  2016          Smirnoff Orange
# 7           2500  2016-05-18      5  2016  Kraken Black Spiced Rum
# 8           2500  2016-05-25      5  2016           Godiva Liqueur
# 64          2500  2020-05-06      5  2020             Jameson Mini
#
#                      1                            2                    3  \
# 5           Lady Bligh                         None                 None
# 6                 None                         None                 None
# 7                 None                         None                 None
# 8                 None                         None                 None
# 64  Malibu Coconut Rum  Dekuyper Luscious Peachtree  Tomatin Single Malt
#
#                  4               5  ...   820   821   822   823   824   825  \
# 5             None            None  ...  None  None  None  None  None  None
# 6             None            None  ...  None  None  None  None  None  None
# 7             None            None  ...  None  None  None  None  None  None
# 8             None            None  ...  None  None  None  None  None  None
# 64  RumChata Limon  Jim Beam Honey  ...  None  None  None  None  None  None
#
#      826   827   828   829
# 5   None  None  None  None
# 6   None  None  None  None
# 7   None  None  None  None
# 8   None  None  None  None
# 64  None  None  None  None
#
# [5 rows x 834 columns]

# %%
num_rows = 1263
num_cols = 834
may_transactions = mba_df.iloc[:num_rows, 4:num_cols].astype(str).values.tolist()

rules = apriori(transactions = may_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
may_results = list(rules)

def inspect(may_results):
    lhs         = [tuple(result[2][0][0])[0] for result in may_results]
    rhs         = [tuple(result[2][0][1])[0] for result in may_results]
    supports    = [result[1] for result in may_results]
    confidences = [result[2][0][2] for result in may_results]
    lifts       = [result[2][0][3] for result in may_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

may_resultsinDataFrame = pd.DataFrame(inspect(may_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
may_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                                        Left Hand Side  \
# 33588                           Truly Pineapple Mango
# 29416  Natural Light Black Cherry Lemonade Vodka Mini
# 33589                           Truly Pineapple Mango
# 33594                       Truly Strawberry Lemonade
# 21370                               Flecha Azul Anejo
#
#                          Right Hand Side   Support  Confidence    Lift
# 33588          Truly Strawberry Lemonade  0.003167         1.0  315.75
# 29416  Natural Light Lemonade Vodka Mini  0.003167         1.0  315.75
# 33589                   Truly Wild Berry  0.003167         1.0  315.75
# 33594                   Truly Wild Berry  0.003167         1.0  315.75
# 21370               Flecha Azul Reposado  0.003167         1.0  252.60

# %% [markdown]
# ## June

# %%
jun_mba = mba_df[mba_df["Month"] == 6]
jun_mba.shape
# Out:
# (1364, 834)

# %%
num_rows = 1364
num_cols = 834
jun_transactions = mba_df.iloc[:num_rows, 4:num_cols].astype(str).values.tolist()

rules = apriori(transactions = jun_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
jun_results = list(rules)

def inspect(jun_results):
    lhs         = [tuple(result[2][0][0])[0] for result in jun_results]
    rhs         = [tuple(result[2][0][1])[0] for result in jun_results]
    supports    = [result[1] for result in jun_results]
    confidences = [result[2][0][2] for result in jun_results]
    lifts       = [result[2][0][3] for result in jun_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

jun_resultsinDataFrame = pd.DataFrame(inspect(jun_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
jun_resultsinDataFrame.head()
# Out:
#                  Left Hand Side                   Right Hand Side   Support  \
# 0  1792 Bottled in Bond Bourbon           St Brendans Irish Cream  0.003666
# 1  1792 Bottled in Bond Bourbon                      UV Vodka PET  0.003666
# 2               1792 Full Proof           Beams 8 Star Bl Whiskey  0.006598
# 3               1792 Full Proof                       Calvert Gin  0.005132
# 4               1792 Full Proof  Captain Morgan 100prf Spiced Rum  0.003666
#
#    Confidence       Lift
# 0    0.833333  10.825397
# 1    0.833333   4.963610
# 2    0.600000   3.621239
# 3    0.466667   3.929218
# 4    0.333333   3.953623

# %%
jun_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                                    Left Hand Side  \
# 23842                  Truly Pineapple Mango Mini
# 15066                          Flecha Azul Blanco
# 16490  Grey Goose Essences White Peach & Rosemary
# 20519                        McCormick Vodka Mini
# 12060            Daviess County KSBW Cab Finished
#
#                                         Right Hand Side   Support  Confidence  \
# 23842                             Truly Wild Berry Mini  0.004399    1.000000
# 15066                              Flecha Azul Reposado  0.003666    0.833333
# 16490                Grey Goose Strawberry & Lemongrass  0.003666    0.833333
# 20519                      Rumple Minze Peppermint Mini  0.005132    1.000000
# 12060  Daviess County Kentucky Straight Bourbon Whiskey  0.003666    0.555556
#
#              Lift
# 23842  227.333333
# 15066  227.333333
# 16490  227.333333
# 20519  170.500000
# 12060  151.555556

# %% [markdown]
# ## July

# %%
jul_mba = mba_df[mba_df["Month"] == 7]
jul_mba.shape
# Out:
# (1984, 834)

# %%
num_rows = 1984
num_cols = 834
jul_transactions = mba_df.iloc[:num_rows, 4:num_cols].astype(str).values.tolist()

rules = apriori(transactions = jul_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
jul_results = list(rules)

def inspect(jul_results):
    lhs         = [tuple(result[2][0][0])[0] for result in jul_results]
    rhs         = [tuple(result[2][0][1])[0] for result in jul_results]
    supports    = [result[1] for result in jul_results]
    confidences = [result[2][0][2] for result in jul_results]
    lifts       = [result[2][0][3] for result in jul_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

jul_resultsinDataFrame = pd.DataFrame(inspect(jul_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
jan_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                           Left Hand Side  \
# 23737          Truly Strawberry Lemonade
# 23735              Truly Pineapple Mango
# 23734              Truly Pineapple Mango
# 15056                  Flecha Azul Anejo
# 20683  Natural Light Lemonade Vodka Mini
#
#                                     Right Hand Side   Support  Confidence  \
# 23737                              Truly Wild Berry  0.003156    1.000000
# 23735                              Truly Wild Berry  0.003156    1.000000
# 23734                     Truly Strawberry Lemonade  0.003156    1.000000
# 15056                          Flecha Azul Reposado  0.003156    1.000000
# 20683  Natural Light Strawberry Lemonade Vodka Mini  0.003156    0.857143
#
#              Lift
# 23737  316.833333
# 23735  316.833333
# 23734  316.833333
# 15056  271.571429
# 20683  271.571429

# %% [markdown]
# ## August

# %%
aug_mba = mba_df[mba_df["Month"] == 8]
aug_mba.shape
# Out:
# (1302, 834)

# %%
num_rows = 1302
num_cols = 834
aug_transactions = mba_df.iloc[:num_rows, 4:num_cols].astype(str).values.tolist()

rules = apriori(transactions = aug_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
aug_results = list(rules)

def inspect(aug_results):
    lhs         = [tuple(result[2][0][0])[0] for result in aug_results]
    rhs         = [tuple(result[2][0][1])[0] for result in aug_results]
    supports    = [result[1] for result in aug_results]
    confidences = [result[2][0][2] for result in aug_results]
    lifts       = [result[2][0][3] for result in aug_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

aug_resultsinDataFrame = pd.DataFrame(inspect(aug_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
aug_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                                        Left Hand Side  \
# 32904                       Truly Strawberry Lemonade
# 28844  Natural Light Black Cherry Lemonade Vodka Mini
# 32899                           Truly Pineapple Mango
# 32898                           Truly Pineapple Mango
# 29228          North Forest Kreme Maple Bourbon Pecan
#
#                          Right Hand Side   Support  Confidence   Lift
# 32904                   Truly Wild Berry  0.003072         1.0  325.5
# 28844  Natural Light Lemonade Vodka Mini  0.003072         1.0  325.5
# 32899                   Truly Wild Berry  0.003072         1.0  325.5
# 32898          Truly Strawberry Lemonade  0.003072         1.0  325.5
# 29228          North Forest Kreme Walnut  0.003072         0.8  260.4

# %% [markdown]
# ## September

# %%
sept_mba = mba_df[mba_df["Month"] == 9]
sept_mba.shape
# Out:
# (1217, 834)

# %%
num_rows = 1217
num_cols = 834
sept_transactions = mba_df.iloc[:num_rows, 4:num_cols].astype(str).values.tolist()

rules = apriori(transactions = sept_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
sept_results = list(rules)

def inspect(sept_results):
    lhs         = [tuple(result[2][0][0])[0] for result in sept_results]
    rhs         = [tuple(result[2][0][1])[0] for result in sept_results]
    supports    = [result[1] for result in sept_results]
    confidences = [result[2][0][2] for result in sept_results]
    lifts       = [result[2][0][3] for result in sept_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

sept_resultsinDataFrame = pd.DataFrame(inspect(sept_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
sept_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                                        Left Hand Side  \
# 33922                           Truly Pineapple Mango
# 29713  Natural Light Black Cherry Lemonade Vodka Mini
# 33928                       Truly Strawberry Lemonade
# 33923                           Truly Pineapple Mango
# 30104          North Forest Kreme Maple Bourbon Pecan
#
#                          Right Hand Side   Support  Confidence    Lift
# 33922          Truly Strawberry Lemonade  0.003287         1.0  304.25
# 29713  Natural Light Lemonade Vodka Mini  0.003287         1.0  304.25
# 33928                   Truly Wild Berry  0.003287         1.0  304.25
# 33923                   Truly Wild Berry  0.003287         1.0  304.25
# 30104          North Forest Kreme Walnut  0.003287         0.8  243.40

# %% [markdown]
# ## October

# %%
oct_mba = mba_df[mba_df["Month"] == 10]
oct_mba.shape
# Out:
# (709, 834)

# %%
num_rows = 709
num_cols = 834
oct_transactions = mba_df.iloc[:num_rows, 4:num_cols].astype(str).values.tolist()

rules = apriori(transactions = oct_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
oct_results = list(rules)

def inspect(oct_results):
    lhs         = [tuple(result[2][0][0])[0] for result in oct_results]
    rhs         = [tuple(result[2][0][1])[0] for result in oct_results]
    supports    = [result[1] for result in oct_results]
    confidences = [result[2][0][2] for result in oct_results]
    lifts       = [result[2][0][3] for result in oct_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

oct_resultsinDataFrame = pd.DataFrame(inspect(oct_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
oct_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                                          Left Hand Side  \
# 52944                        Truly Pineapple Mango Mini
# 52943                             Truly Pineapple Mango
# 52942                             Truly Pineapple Mango
# 36489       Grey Goose Essences Watermelon & Basil Mini
# 36475  Grey Goose Essences Strawberry & Lemongrass Mini
#
#                                        Right Hand Side   Support  Confidence  \
# 52944                            Truly Wild Berry Mini  0.004231         1.0
# 52943                                 Truly Wild Berry  0.004231         1.0
# 52942                        Truly Strawberry Lemonade  0.004231         1.0
# 36489  Grey Goose Essences White Peach & Rosemary Mini  0.004231         1.0
# 36475  Grey Goose Essences White Peach & Rosemary Mini  0.004231         1.0
#
#              Lift
# 52944  236.333333
# 52943  236.333333
# 52942  236.333333
# 36489  236.333333
# 36475  236.333333

# %% [markdown]
# ## November

# %%
nov_mba = mba_df[mba_df["Month"] == 11]
nov_mba.shape
# Out:
# (1385, 834)

# %%
num_rows = 1385
num_cols = 834
nov_transactions = mba_df.iloc[:num_rows, 4:num_cols].astype(str).values.tolist()

rules = apriori(transactions = nov_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
nov_results = list(rules)

def inspect(nov_results):
    lhs         = [tuple(result[2][0][0])[0] for result in nov_results]
    rhs         = [tuple(result[2][0][1])[0] for result in nov_results]
    supports    = [result[1] for result in nov_results]
    confidences = [result[2][0][2] for result in nov_results]
    lifts       = [result[2][0][3] for result in nov_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

nov_resultsinDataFrame = pd.DataFrame(inspect(nov_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
nov_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                                    Left Hand Side  \
# 16599  Grey Goose Essences White Peach & Rosemary
# 23999                  Truly Pineapple Mango Mini
# 15174                          Flecha Azul Blanco
# 21299      North Forest Kreme Maple Bourbon Pecan
# 20652                        McCormick Vodka Mini
#
#                           Right Hand Side   Support  Confidence        Lift
# 16599  Grey Goose Strawberry & Lemongrass  0.003610    0.833333  230.833333
# 23999               Truly Wild Berry Mini  0.004332    1.000000  230.833333
# 15174                Flecha Azul Reposado  0.003610    0.833333  230.833333
# 21299           North Forest Kreme Walnut  0.003610    0.833333  230.833333
# 20652        Rumple Minze Peppermint Mini  0.005054    1.000000  173.125000

# %% [markdown]
# ## December

# %%
dec_mba = mba_df[mba_df["Month"] == 12]
dec_mba.shape
# Out:
# (1753, 834)

# %%
num_rows = 1753
num_cols = 834
dec_transactions = mba_df.iloc[:num_rows, 4:num_cols].astype(str).values.tolist()

rules = apriori(transactions = dec_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
dec_results = list(rules)

def inspect(dec_results):
    lhs         = [tuple(result[2][0][0])[0] for result in dec_results]
    rhs         = [tuple(result[2][0][1])[0] for result in dec_results]
    supports    = [result[1] for result in dec_results]
    confidences = [result[2][0][2] for result in dec_results]
    lifts       = [result[2][0][3] for result in dec_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

dec_resultsinDataFrame = pd.DataFrame(inspect(dec_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
dec_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                                        Left Hand Side  \
# 23925                       Truly Strawberry Lemonade
# 23923                           Truly Pineapple Mango
# 20874  Natural Light Black Cherry Lemonade Vodka Mini
# 23922                           Truly Pineapple Mango
# 15178                              Flecha Azul Blanco
#
#                          Right Hand Side   Support  Confidence        Lift
# 23925                   Truly Wild Berry  0.003423    1.000000  292.166667
# 23923                   Truly Wild Berry  0.003423    1.000000  292.166667
# 20874  Natural Light Lemonade Vodka Mini  0.003423    1.000000  292.166667
# 23922          Truly Strawberry Lemonade  0.003423    1.000000  292.166667
# 15178               Flecha Azul Reposado  0.003423    0.857143  250.428571

# %% [markdown]
# # What happens if we condition on different types of stores (chain-super markets, specialized liquor stores, small convenience stores, news stands)?

# %%
mba_df2 = pd.read_csv("mba_df2.csv", index_col = [0]) # index_col = [0] removes unnmaed index column
path = 'mba_df2.feather'
feather.write_dataframe(mba_df2, path)
mba_df2 = feather.read_dataframe(path)

# %%
mba_df2.head()
# Out:
#    Store Number        Date  Month  Year  County Number Store Category  \
# 0          2500  2016-03-23      3  2016             85     Food Store
# 1          2500  2016-03-30      3  2016             85     Food Store
# 2          2500  2016-04-13      4  2016             85     Food Store
# 3          2500  2016-04-20      4  2016             85     Food Store
# 4          2500  2016-04-27      4  2016             85     Food Store
#
#                           0                     1                          2  \
# 0             Hawkeye Vodka                  None                       None
# 1        Popov Vodka 80 Prf              Old Crow  Captain Morgan Spiced Rum
# 2                  Old Crow  Paramount Triple Sec    Bushmills Irish Whiskey
# 3  Burnett's Gin London Dry       Bacardi 151 Prf  Bailey's Vanilla Cinnamon
# 4          Southern Comfort                  None                       None
#
#                      3  ...   820   821   822   823   824   825   826   827  \
# 0                 None  ...  None  None  None  None  None  None  None  None
# 1        Five Star Pet  ...  None  None  None  None  None  None  None  None
# 2                 None  ...  None  None  None  None  None  None  None  None
# 3  1800 Silver Tequila  ...  None  None  None  None  None  None  None  None
# 4                 None  ...  None  None  None  None  None  None  None  None
#
#     828   829
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None
#
# [5 rows x 836 columns]

# %%
mba_df2["Store Category"].unique()
# Out:
# array(['Food Store', 'Supermarket', 'Wine & Spirits', 'Drugstore',
#        'Food & Drugstore', 'Gas', 'Fast & Fresh'], dtype=object)

# %% [markdown]
# ### Food Store

# %%
food_mba = mba_df2[mba_df2["Store Category"] == "Food Store"]
food_mba.shape
# Out:
# (7683, 836)

# %%
num_rows = 7683
num_cols = 836
food_transactions = mba_df2.iloc[:num_rows, 6:num_cols].astype(str).values.tolist()

rules = apriori(transactions = food_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
food_results = list(rules)

def inspect(food_results):
    lhs         = [tuple(result[2][0][0])[0] for result in food_results]
    rhs         = [tuple(result[2][0][1])[0] for result in food_results]
    supports    = [result[1] for result in food_results]
    confidences = [result[2][0][2] for result in food_results]
    lifts       = [result[2][0][3] for result in food_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

food_resultsinDataFrame = pd.DataFrame(inspect(food_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
food_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                   Left Hand Side            Right Hand Side   Support  \
# 3688   Truly Strawberry Lemonade           Truly Wild Berry  0.003124
# 3685       Truly Pineapple Mango  Truly Strawberry Lemonade  0.003384
# 3686       Truly Pineapple Mango           Truly Wild Berry  0.003124
# 3687  Truly Pineapple Mango Mini      Truly Wild Berry Mini  0.004035
# 3726           White Dog Mash #1            White Dog Wheat  0.005076
#
#       Confidence        Lift
# 3688    0.923077  295.500000
# 3685    1.000000  295.500000
# 3686    0.923077  295.500000
# 3687    1.000000  207.648649
# 3726    1.000000  187.390244

# %% [markdown]
# ### Supermarket

# %%
supermarket_mba = mba_df2[mba_df2["Store Category"] == "Supermarket"]
supermarket_mba.shape
# Out:
# (4633, 836)

# %%
num_rows = 4633
num_cols = 836
supermarket_transactions = mba_df2.iloc[:num_rows, 6:num_cols].astype(str).values.tolist()

rules = apriori(transactions = supermarket_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
supermarket_results = list(rules)

def inspect(supermarket_results):
    lhs         = [tuple(result[2][0][0])[0] for result in supermarket_results]
    rhs         = [tuple(result[2][0][1])[0] for result in supermarket_results]
    supports    = [result[1] for result in supermarket_results]
    confidences = [result[2][0][2] for result in supermarket_results]
    lifts       = [result[2][0][3] for result in supermarket_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

supermarket_resultsinDataFrame = pd.DataFrame(inspect(supermarket_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
supermarket_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                   Left Hand Side                Right Hand Side   Support  \
# 5774  Truly Pineapple Mango Mini          Truly Wild Berry Mini  0.004317
# 5817           White Dog Mash #1                White Dog Wheat  0.004317
# 5816           White Dog Mash #1         White Dog Straight Rye  0.004317
# 5818      White Dog Straight Rye                White Dog Wheat  0.004749
# 1633          Branson VS Phantom  Branson VSOP Grande Champagne  0.003885
#
#       Confidence        Lift
# 5774    1.000000  220.619048
# 5817    1.000000  210.590909
# 5816    1.000000  210.590909
# 5818    1.000000  210.590909
# 1633    0.692308  133.644231

# %% [markdown]
# ### Wine & Spirits

# %%
wine_spirits_mba = mba_df2[mba_df2["Store Category"] == "Wine & Spirits"]
wine_spirits_mba.shape
# Out:
# (3164, 836)

# %%
num_rows = 3164
num_cols = 836
wine_spirit_transactions = mba_df2.iloc[:num_rows, 6:num_cols].astype(str).values.tolist()

rules = apriori(transactions = wine_spirit_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
wine_spirit_results = list(rules)

def inspect(supermarket_results):
    lhs         = [tuple(result[2][0][0])[0] for result in wine_spirit_results]
    rhs         = [tuple(result[2][0][1])[0] for result in wine_spirit_results]
    supports    = [result[1] for result in wine_spirit_results]
    confidences = [result[2][0][2] for result in wine_spirit_results]
    lifts       = [result[2][0][3] for result in wine_spirit_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

wine_spirit_resultsinDataFrame = pd.DataFrame(inspect(wine_spirit_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
wine_spirit_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                                Left Hand Side  \
# 12432              Truly Pineapple Mango Mini
# 7788                       Flecha Azul Blanco
# 8826   Grey Goose Essences Watermelon & Basil
# 9311       Issac Bowman Port Finished Bourbon
# 12488                       White Dog Mash #1
#
#                           Right Hand Side   Support  Confidence        Lift
# 12432               Truly Wild Berry Mini  0.003477    1.000000  287.636364
# 7788                 Flecha Azul Reposado  0.003477    0.916667  263.666667
# 8826   Grey Goose Strawberry & Lemongrass  0.003477    1.000000  243.384615
# 9311                John J Bowman Bourbon  0.003161    0.833333  239.696970
# 12488              White Dog Straight Rye  0.005057    1.000000  186.117647

# %% [markdown]
# ### Drugstore

# %%
drugstore_mba = mba_df2[mba_df2["Store Category"] == "Drugstore"]
drugstore_mba.shape
# Out:
# (1341, 836)

# %%
num_rows = 1341
num_cols = 836
drugstore_transactions = mba_df2.iloc[:num_rows, 6:num_cols].astype(str).values.tolist()

rules = apriori(transactions = drugstore_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
drugstore_results = list(rules)

def inspect(drugstore_results):
    lhs         = [tuple(result[2][0][0])[0] for result in drugstore_results]
    rhs         = [tuple(result[2][0][1])[0] for result in drugstore_results]
    supports    = [result[1] for result in drugstore_results]
    confidences = [result[2][0][2] for result in drugstore_results]
    lifts       = [result[2][0][3] for result in drugstore_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

drugstore_resultsinDataFrame = pd.DataFrame(inspect(drugstore_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
drugstore_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                          Left Hand Side  \
# 23151        Truly Pineapple Mango Mini
# 14677                Flecha Azul Blanco
# 19936              McCormick Vodka Mini
# 11737  Daviess County KSBW Cab Finished
# 23091          Three Olives Pomegranate
#
#                                         Right Hand Side   Support  Confidence  \
# 23151                             Truly Wild Berry Mini  0.004474    1.000000
# 14677                              Flecha Azul Reposado  0.003729    0.833333
# 19936                      Rumple Minze Peppermint Mini  0.005220    1.000000
# 11737  Daviess County Kentucky Straight Bourbon Whiskey  0.003729    0.555556
# 23091                            Three Olives Raspberry  0.004474    0.750000
#
#              Lift
# 23151  223.500000
# 14677  223.500000
# 19936  167.625000
# 11737  149.000000
# 23091  143.678571

# %% [markdown]
# ### Food & Drugstore

# %%
food_drug_mba = mba_df2[mba_df2["Store Category"] == "Food & Drugstore"]
food_drug_mba.shape
# Out:
# (381, 836)

# %%
num_rows = 381
num_cols = 836
food_drug_transactions = mba_df2.iloc[:num_rows, 6:num_cols].astype(str).values.tolist()

rules = apriori(transactions = food_drug_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
food_drug_results = list(rules)

def inspect(food_drug_results):
    lhs         = [tuple(result[2][0][0])[0] for result in food_drug_results]
    rhs         = [tuple(result[2][0][1])[0] for result in food_drug_results]
    supports    = [result[1] for result in food_drug_results]
    confidences = [result[2][0][2] for result in food_drug_results]
    lifts       = [result[2][0][3] for result in food_drug_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

food_drug_resultsinDataFrame = pd.DataFrame(inspect(food_drug_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
food_drug_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                        Left Hand Side                       Right Hand Side  \
# 59532  Milagro Select Barrel Reposado  Milagro Select Barrel Silver Tequila
# 67679           Truly Pineapple Mango             Truly Strawberry Lemonade
# 52049             Jameson Orange Mini    Revel Stoke Root of Evil Root Beer
# 31193    Codigo 1530 Tequila Reposado       Codigo 1530 Tequila Rosa Blanco
# 29935           Cincoro Anejo Tequila              Cincoro Reposado Tequila
#
#         Support  Confidence   Lift
# 59532  0.005249         1.0  190.5
# 67679  0.005249         1.0  190.5
# 52049  0.005249         1.0  190.5
# 31193  0.005249         1.0  190.5
# 29935  0.005249         1.0  190.5

# %% [markdown]
# ### Gas

# %%
gas_mba = mba_df2[mba_df2["Store Category"] == "Gas"]
gas_mba.shape
# Out:
# (245, 836)

# %%
num_rows = 245
num_cols = 836
gas_transactions = mba_df2.iloc[:num_rows, 6:num_cols].astype(str).values.tolist()

rules = apriori(transactions = gas_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
gas_results = list(rules)

def inspect(gas_results):
    lhs         = [tuple(result[2][0][0])[0] for result in gas_results]
    rhs         = [tuple(result[2][0][1])[0] for result in gas_results]
    supports    = [result[1] for result in gas_results]
    confidences = [result[2][0][2] for result in gas_results]
    lifts       = [result[2][0][3] for result in gas_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

gas_resultsinDataFrame = pd.DataFrame(inspect(gas_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
gas_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                            Left Hand Side  \
# 15167     Appleton Estate Signature Blend
# 62807   Combier Pamplemousse Rose Liqueur
# 104824         Jagermeister Mini Meisters
# 62894         Combier Peche Vigne Liqueur
# 35846     Blue Chair Bay Banana Rum Cream
#
#                              Right Hand Side   Support  Confidence   Lift
# 15167   Early Times 36 Mo Ky Str Bourbon PET  0.004082         1.0  245.0
# 62807                    Glen Moray Cabernet  0.004082         1.0  245.0
# 104824                       McCormick Vodka  0.004082         1.0  245.0
# 62894                  Evan Williams Vintage  0.004082         1.0  245.0
# 35846                    Burnetts Peach Mini  0.004082         1.0  245.0

# %% [markdown]
# ### Fast & Fresh

# %%
fast_fresh_mba = mba_df2[mba_df2["Store Category"] == "Fast & Fresh"]
fast_fresh_mba.shape
# Out:
# (663, 836)

# %%
num_rows = 663
num_cols = 836
fast_fresh_transactions = mba_df2.iloc[:num_rows, 6:num_cols].astype(str).values.tolist()

rules = apriori(transactions = fast_fresh_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
fast_fresh_results = list(rules)

def inspect(fast_fresh_results):
    lhs         = [tuple(result[2][0][0])[0] for result in fast_fresh_results]
    rhs         = [tuple(result[2][0][1])[0] for result in fast_fresh_results]
    supports    = [result[1] for result in fast_fresh_results]
    confidences = [result[2][0][2] for result in fast_fresh_results]
    lifts       = [result[2][0][3] for result in fast_fresh_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

fast_fresh_resultsinDataFrame = pd.DataFrame(inspect(fast_fresh_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
fast_fresh_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                    Left Hand Side  \
# 50139  Devils Sister Kentucky 5YR
# 51508    Door County Cherry Vodka
# 60080           Flecha Azul Anejo
# 60081           Flecha Azul Anejo
# 60084          Flecha Azul Blanco
#
#                                        Right Hand Side   Support  Confidence  \
# 50139                              Devils Sister Peach  0.003017         1.0
# 51508  El Mayor Extra Anejo Sherry Cask Finish Tequila  0.003017         1.0
# 60080                               Flecha Azul Blanco  0.003017         1.0
# 60081                             Flecha Azul Reposado  0.003017         1.0
# 60084                             Flecha Azul Reposado  0.003017         1.0
#
#         Lift
# 50139  331.5
# 51508  331.5
# 60080  331.5
# 60081  331.5
# 60084  331.5

# %% [markdown]
# ## By season

# %% [markdown]
# - Spring: March, April, May (3, 4, 5)
# - Summer: June, July, August (6, 7, 8)
# - Fall: September, October, November (9, 10, 11)
# - Winter: December, January, February (12, 1, 2)

# %%
mba_df2.head()
# Out:
#    Store Number        Date  Month  Year  County Number Store Category  \
# 0          2500  2016-03-23      3  2016             85     Food Store
# 1          2500  2016-03-30      3  2016             85     Food Store
# 2          2500  2016-04-13      4  2016             85     Food Store
# 3          2500  2016-04-20      4  2016             85     Food Store
# 4          2500  2016-04-27      4  2016             85     Food Store
#
#                           0                     1                          2  \
# 0             Hawkeye Vodka                  None                       None
# 1        Popov Vodka 80 Prf              Old Crow  Captain Morgan Spiced Rum
# 2                  Old Crow  Paramount Triple Sec    Bushmills Irish Whiskey
# 3  Burnett's Gin London Dry       Bacardi 151 Prf  Bailey's Vanilla Cinnamon
# 4          Southern Comfort                  None                       None
#
#                      3  ...   820   821   822   823   824   825   826   827  \
# 0                 None  ...  None  None  None  None  None  None  None  None
# 1        Five Star Pet  ...  None  None  None  None  None  None  None  None
# 2                 None  ...  None  None  None  None  None  None  None  None
# 3  1800 Silver Tequila  ...  None  None  None  None  None  None  None  None
# 4                 None  ...  None  None  None  None  None  None  None  None
#
#     828   829
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None
#
# [5 rows x 836 columns]

# %% [markdown]
# ### Spring

# %%
spring_df = mba_df2[(mba_df2["Month"] == 3) | (mba_df2["Month"] == 4) | (mba_df2["Month"] == 5)]
spring_df.shape
# Out:
# (4658, 836)

# %%
num_rows = 4658
num_cols = 836
spring_transactions = mba_df2.iloc[:num_rows, 6:num_cols].astype(str).values.tolist()

rules = apriori(transactions = spring_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
spring_results = list(rules)

def inspect(spring_results):
    lhs         = [tuple(result[2][0][0])[0] for result in spring_results]
    rhs         = [tuple(result[2][0][1])[0] for result in spring_results]
    supports    = [result[1] for result in spring_results]
    confidences = [result[2][0][2] for result in spring_results]
    lifts       = [result[2][0][3] for result in spring_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

spring_resultsinDataFrame = pd.DataFrame(inspect(spring_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
spring_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                   Left Hand Side         Right Hand Side   Support  \
# 5877  Truly Pineapple Mango Mini   Truly Wild Berry Mini  0.004294
# 5920           White Dog Mash #1  White Dog Straight Rye  0.004294
# 5921           White Dog Mash #1         White Dog Wheat  0.004294
# 5922      White Dog Straight Rye         White Dog Wheat  0.004723
# 2814    Deep Eddy Cranberry Mini    Deep Eddy Peach Mini  0.003006
#
#       Confidence        Lift
# 5877         1.0  221.809524
# 5920         1.0  211.727273
# 5921         1.0  211.727273
# 5922         1.0  211.727273
# 2814         0.7  141.765217

# %%
spring_resultsinDataFrame.sort_values(by=["Support"], ascending = False).head()
# Out:
#              Left Hand Side        Right Hand Side   Support  Confidence  \
# 759     Ancient Age Bourbon  Buffalo Trace Bourbon  0.049377    0.699088
# 1693  Buffalo Trace Bourbon             Eagle Rare  0.047660    0.355769
# 1520       Blantons Bourbon  Buffalo Trace Bourbon  0.045298    0.861224
# 4608        Kinky Blue Mini        Kinky Pink Mini  0.044010    0.457589
# 1704         Bulleit 95 Rye        Bulleit Bourbon  0.036926    0.452632
#
#           Lift
# 759   5.218514
# 1693  6.576084
# 1520  6.428820
# 4608  3.991481
# 1704  3.029250

# %% [markdown]
# ### Summer

# %%
summer_df = mba_df2[(mba_df2["Month"] == 6) | (mba_df2["Month"] == 7) | (mba_df2["Month"] == 8)]
summer_df.shape
# Out:
# (4650, 836)

# %%
num_rows = 4650
num_cols = 836
summer_transactions = mba_df2.iloc[:num_rows, 6:num_cols].astype(str).values.tolist()

rules = apriori(transactions = summer_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
summer_results = list(rules)

def inspect(summer_results):
    lhs         = [tuple(result[2][0][0])[0] for result in summer_results]
    rhs         = [tuple(result[2][0][1])[0] for result in summer_results]
    supports    = [result[1] for result in summer_results]
    confidences = [result[2][0][2] for result in summer_results]
    lifts       = [result[2][0][3] for result in summer_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

summer_resultsinDataFrame = pd.DataFrame(inspect(summer_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
summer_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                   Left Hand Side         Right Hand Side   Support  \
# 5854  Truly Pineapple Mango Mini   Truly Wild Berry Mini  0.004301
# 5899      White Dog Straight Rye         White Dog Wheat  0.004731
# 5898           White Dog Mash #1         White Dog Wheat  0.004301
# 5897           White Dog Mash #1  White Dog Straight Rye  0.004301
# 2811    Deep Eddy Cranberry Mini    Deep Eddy Peach Mini  0.003011
#
#       Confidence        Lift
# 5854         1.0  221.428571
# 5899         1.0  211.363636
# 5898         1.0  211.363636
# 5897         1.0  211.363636
# 2811         0.7  141.521739

# %% [markdown]
# ### Fall

# %%
fall_df = mba_df2[(mba_df2["Month"] == 9) | (mba_df2["Month"] == 10) | (mba_df2["Month"] == 11)]
fall_df.shape
# Out:
# (3311, 836)

# %%
num_rows = 3311
num_cols = 836
fall_transactions = mba_df2.iloc[:num_rows, 6:num_cols].astype(str).values.tolist()

rules = apriori(transactions = fall_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
fall_results = list(rules)

def inspect(fall_results):
    lhs         = [tuple(result[2][0][0])[0] for result in fall_results]
    rhs         = [tuple(result[2][0][1])[0] for result in fall_results]
    supports    = [result[1] for result in fall_results]
    confidences = [result[2][0][2] for result in fall_results]
    lifts       = [result[2][0][3] for result in fall_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

fall_resultsinDataFrame = pd.DataFrame(inspect(fall_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
fall_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                                Left Hand Side  \
# 8554   Grey Goose Essences Watermelon & Basil
# 7542                       Flecha Azul Blanco
# 9032       Issac Bowman Port Finished Bourbon
# 12040              Truly Pineapple Mango Mini
# 12097                  White Dog Straight Rye
#
#                           Right Hand Side   Support  Confidence        Lift
# 8554   Grey Goose Strawberry & Lemongrass  0.003322    1.000000  254.692308
# 7542                 Flecha Azul Reposado  0.003322    0.846154  254.692308
# 9032                John J Bowman Bourbon  0.003020    0.833333  250.833333
# 12040               Truly Wild Berry Mini  0.003926    1.000000  236.500000
# 12097                     White Dog Wheat  0.005134    1.000000  194.764706

# %% [markdown]
# ### Winter

# %%
winter_df = mba_df2[(mba_df2["Month"] == 12) | (mba_df2["Month"] == 1) | (mba_df2["Month"] == 2)]
winter_df.shape
# Out:
# (5491, 836)

# %%
num_rows = 5491
num_cols = 836
winter_transactions = mba_df2.iloc[:num_rows, 6:num_cols].astype(str).values.tolist()

rules = apriori(transactions = winter_transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
winter_results = list(rules)

def inspect(winter_results):
    lhs         = [tuple(result[2][0][0])[0] for result in winter_results]
    rhs         = [tuple(result[2][0][1])[0] for result in winter_results]
    supports    = [result[1] for result in winter_results]
    confidences = [result[2][0][2] for result in winter_results]
    lifts       = [result[2][0][3] for result in winter_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

winter_resultsinDataFrame = pd.DataFrame(inspect(winter_results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
winter_resultsinDataFrame.sort_values(by=["Lift"], ascending = False).head()
# Out:
#                                          Left Hand Side  \
# 4581                                  White Dog Mash #1
# 4582                             White Dog Straight Rye
# 4580                                  White Dog Mash #1
# 4542                         Truly Pineapple Mango Mini
# 4453  Smirnoff Zero Sugar Infusion Cucumber & Lime Mini
#
#                                         Right Hand Side   Support  Confidence  \
# 4581                                    White Dog Wheat  0.003824    1.000000
# 4582                                    White Dog Wheat  0.004189    1.000000
# 4580                             White Dog Straight Rye  0.003824    1.000000
# 4542                              Truly Wild Berry Mini  0.004189    1.000000
# 4453  Smirnoff Zero Sugar Infusion Watermelon & Mint...  0.003278    0.818182
#
#             Lift
# 4581  238.739130
# 4582  238.739130
# 4580  238.739130
# 4542  228.791667
# 4453  179.705455
